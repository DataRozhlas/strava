# %%
import polars as pl

# %%
df = pl.scan_ndjson("downloads/segments/2024-12-28/.json")

# %%
df.collect()
# Out:
# ---------------------------------------------------------------------------
# SchemaError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df.collect()
#
# File ~\anaconda3\Lib\site-packages\polars\lazyframe\frame.py:2050, in LazyFrame.collect(self, type_coercion, predicate_pushdown, projection_pushdown, simplify_expression, slice_pushdown, comm_subplan_elim, comm_subexpr_elim, cluster_with_columns, collapse_joins, no_optimization, streaming, engine, background, _eager, **_kwargs)
#    2048 # Only for testing purposes
#    2049 callback = _kwargs.get("post_opt_callback", callback)
# -> 2050 return wrap_df(ldf.collect(callback))
#
# SchemaError: type UInt64 is incompatible with expected type Null
